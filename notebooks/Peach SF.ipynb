# %%
import pandas as pd
from IPython.display import display
import folium

# %%
df = pd.read_csv('../data/Street_Tree_List.csv')

# %%
peach_trees = ["peach", "nectarine"]

# %%
peach = df[df['qSpecies'].str.contains('|'.join(peach_trees), case=False)]
peach = peach.dropna(subset=['Latitude', 'Longitude'])
peach
# Out:
#         TreeID    qLegalStatus  \
# 3381    246613  DPW Maintained
# 4616    196370  DPW Maintained
# 14966   214376  DPW Maintained
# 19037   196364  DPW Maintained
# 21960   101445  DPW Maintained
# 24032   135886  DPW Maintained
# 28478   237966  DPW Maintained
# 42481   135890  DPW Maintained
# 42797   178865  DPW Maintained
# 43323   196359  DPW Maintained
# 48178   143435  DPW Maintained
# 50695   196362  DPW Maintained
# 52431   196358  DPW Maintained
# 58767   135889  DPW Maintained
# 58900   202146  DPW Maintained
# 59956   237967  DPW Maintained
# 62094   178870  DPW Maintained
# 69825   214379  DPW Maintained
# 69925   184384  DPW Maintained
# 72816   135885  DPW Maintained
# 74044   135887  DPW Maintained
# 76784   135884  DPW Maintained
# 82648   237970  DPW Maintained
# 83077   201334  DPW Maintained
# 84931   196360  DPW Maintained
# 90219   178866  DPW Maintained
# 96298    87817  DPW Maintained
# 99092   196366  DPW Maintained
# 100801  178868  DPW Maintained
# ...

# %%
peach['qSpecies'].value_counts()
# Out:
# qSpecies
# Prunus persica :: Peach                                 53
# Prunus persica nectarina :: Flowering Nectarine Tree     1
# Name: count, dtype: int64
